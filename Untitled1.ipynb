# %%
import numpy as np
import os
import glob
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
dsdir = "C:/Users/temmuz/Desktop/2022-2/proje/stanford/dataset"
class_count = np.zeros((6,11))
for i in range(6):
    dsdiri = dsdir+"/"+str(i)
    for j in range(11):
        dsdirij = dsdiri+"/"+str(j)+'/*.jpg'
        class_count[i,j] += len(glob.glob(dsdirij))

# %%
sum(class_count,1)
# Out:
# array([29151.,  3851.,  6372.,  2350.,   925., 22379.,   241.,   419.,
#          875.,  1778.,  2166.])

# %%
data_dir = "C:/Users/temmuz/Desktop/2022-2/proje/stanford/dataset/0"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(112, 112),
  batch_size=8262)
# Out:
# Found 10327 files belonging to 11 classes.
# Using 8262 files for training.

# %%
train_ds
# Out:
# <BatchDataset shapes: ((None, 112, 112, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
image_names = glob.glob('C:/Users/temmuz/Desktop/2022-2/proje/stanford/dataset/0/0/*.jpg')

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread(image_names[0])
 
# Output Images
plt.imshow(img)

# %%
img2 = img/255.0
plt.imshow(img2)

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['image', 'label'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [image, label]
# Index: []

# %%
df["image"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-471b87702e3f> in <module>
# ----> 1 df["image"][0]
#
# c:\users\temmuz\desktop\tff\tff_env\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     937
#     938         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 939             return self._values[key]
#     940
#     941         elif key_is_scalar:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
data = pd.DataFrame(index=range(1,100),columns=['image', 'label'])

# %%
data
# Out:
#    image label
# 1    NaN   NaN
# 2    NaN   NaN
# 3    NaN   NaN
# 4    NaN   NaN
# 5    NaN   NaN
# ..   ...   ...
# 95   NaN   NaN
# 96   NaN   NaN
# 97   NaN   NaN
# 98   NaN   NaN
# 99   NaN   NaN
#
# [99 rows x 2 columns]

# %%
data.loc[1].image = img2

# %%
data
# Out:
#                                                 image label
# 1   [[[0.6235294117647059, 0.4823529411764706, 0.2...   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# 5                                                 NaN   NaN
# ..                                                ...   ...
# 95                                                NaN   NaN
# 96                                                NaN   NaN
# 97                                                NaN   NaN
# 98                                                NaN   NaN
# 99                                                NaN   NaN
#
# [99 rows x 2 columns]

# %%
data_dir = "C:/Users/temmuz/Desktop/2022-2/proje/stanford/dataset/0"
image_names = []
labels = []
for i in range(11):
    data_dir2 = data_dir+"/"+str(i)+"/*.jpg"
    image_names.extend(glob.glob(data_dir2))
    labels.extend(np.ones(len(glob.glob(data_dir2)),dtype=int)*i)

# %%
data = pd.DataFrame(index=range(len(labels)),columns=['image', 'label'])

# %%
a = [1,3,5]
b = [12,53,6]

# %%
for k,(i,j) in enumerate(zip(a,b)):
    print(k,i,j)
# Out:
# 0 1 12
# 1 3 53
# 2 5 6

# %%
for i, (name, label) in enumerate(zip(image_names,labels)):
    img = mpimg.imread(name)
    img2 = img/255.0
    data.loc[i].image = img2
    data.loc[i].label = label

# %%
data
# Out:
#                                                    image label
# 0      [[[0.6235294117647059, 0.4823529411764706, 0.2...     0
# 1      [[[0.5019607843137255, 0.5058823529411764, 0.4...     0
# 2      [[[0.5568627450980392, 0.5058823529411764, 0.3...     0
# 3      [[[0.5176470588235295, 0.5686274509803921, 0.5...     0
# 4      [[[0.592156862745098, 0.611764705882353, 0.596...     0
# ...                                                  ...   ...
# 10322  [[[0.4196078431372549, 0.3843137254901961, 0.2...    10
# 10323  [[[0.5215686274509804, 0.48627450980392156, 0....    10
# 10324  [[[0.7215686274509804, 0.5450980392156862, 0.3...    10
# 10325  [[[0.6078431372549019, 0.5725490196078431, 0.4...    10
# 10326  [[[0.6, 0.5843137254901961, 0.5411764705882353...    10
#
# [10327 rows x 2 columns]

# %%
data.loc[0].image
# Out:
# array([[[0.62352941, 0.48235294, 0.23921569],
#         [0.61960784, 0.47843137, 0.24313725],
#         [0.61176471, 0.4745098 , 0.24705882],
#         ...,
#         [0.09411765, 0.09803922, 0.11764706],
#         [0.03137255, 0.03921569, 0.09019608],
#         [0.03529412, 0.04705882, 0.11372549]],
#
#        [[0.63137255, 0.49019608, 0.25490196],
#         [0.62352941, 0.49019608, 0.25098039],
#         [0.61960784, 0.48235294, 0.2627451 ],
#         ...,
#         [0.07058824, 0.06666667, 0.08627451],
#         [0.0627451 , 0.07058824, 0.11764706],
#         [0.09803922, 0.10980392, 0.16862745]],
#
#        [[0.63921569, 0.50196078, 0.2745098 ],
#         [0.62745098, 0.50196078, 0.27843137],
#         [0.62352941, 0.49411765, 0.28235294],
#         ...,
#         [0.18431373, 0.17647059, 0.18823529],
#         [0.28235294, 0.28235294, 0.32156863],
#         [0.37254902, 0.38039216, 0.43137255]],
#
#        ...,
#
#        [[0.29411765, 0.17647059, 0.08235294],
#         [0.32941176, 0.21960784, 0.1254902 ],
#         [0.43137255, 0.32156863, 0.22745098],
#         ...,
#         [0.48627451, 0.35686275, 0.19607843],
#         [0.63529412, 0.49803922, 0.33333333],
#         [0.75294118, 0.61960784, 0.44313725]],
#
#        [[0.40784314, 0.29803922, 0.21176471],
#         [0.36862745, 0.25882353, 0.17254902],
#         [0.35686275, 0.24705882, 0.16078431],
#         ...,
#         [0.10196078, 0.05490196, 0.        ],
#         [0.18823529, 0.13333333, 0.08235294],
#         [0.27843137, 0.22352941, 0.17254902]],
#
#        [[0.35294118, 0.24313725, 0.15686275],
#         [0.3372549 , 0.22745098, 0.14117647],
#         [0.34509804, 0.24313725, 0.15294118],
#         ...,
#         [0.05098039, 0.04313725, 0.04705882],
#         [0.09019608, 0.08235294, 0.08627451],
#         [0.15294118, 0.14509804, 0.14901961]]])

# %%
plt.imshow(data.loc[0].image)
